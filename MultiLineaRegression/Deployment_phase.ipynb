# %%
import pickle

# %%
loaded_model=pickle.load(open("Profit_prediction.sav",'rb'))

# %%
result=loaded_model.predict([[46426.07,	157693.92,	210797.67,	False,	False]])
# Out:
# C:\Users\ACER\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[90419.1897851]])
